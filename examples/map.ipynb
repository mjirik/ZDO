# %% [markdown]
# # Do you need a map?
#
# Install [folio](https://github.com/python-visualization/folium) package
#
#         conda install -c ioos folio
#
#
# [simple example](https://app.dominodatalab.com/r00sj3/crimemaps/view/examples.ipynb)
#
# [complex example](https://blog.dominodatalab.com/creating-interactive-crime-maps-with-folium/)

# %%
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import folium
from IPython.display import HTML

map1 = folium.Map(location=[49.726578, 13.352427])
folium.Marker([49.726578, 13.352427], popup='FAV').add_to(map1)
# m.add_children(folium.Marker([49.726578, 13.352427]))
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map.save("map.html")
